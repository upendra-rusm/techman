# %% [markdown]
# # Scatter Plot using seaborn

# %%
import pandas as pd
import seaborn as sns

# %%
train=pd.read_csv("../datasets/train.csv")
sns.scatterplot(train.Fare,train.Age,alpha=.4) # alpha is gradiant colour for plotting
# Out:
# C:\Users\Upendra\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Fare', ylabel='Age'>

# %%
ax = sns.boxplot(train.Fare)
# Out:
# C:\Users\Upendra\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
